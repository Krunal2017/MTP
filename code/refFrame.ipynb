# %%
import cv2
import argparse
import imutils
import time
import scipy.io
# from sklearn.svm import SVC
import skvideo.io
from sklearn.decomposition import PCA
# from sklearn.manifold import Isomap
# from sklearn.manifold import LocallyLinearEmbedding
# from scipy.ndimage import morphology as mp
# from skimage.feature import canny
from thundersvm import SVC
from random import sample
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.neighbors import KNeighborsClassifier
# from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV
from sklearn.feature_extraction import image
from random import shuffle
import numpy as np
import matplotlib.pyplot as plt
import mahotas
from imutils.video import VideoStream
from imutils.video import FPS
import os
import pickle
import copy

# %%
def trainVideo(file,boxes,label,filename):
    vs = cv2.VideoCapture(file)
    
    # loop over frames from the video stream
    fno = 1
    
#     X=None
#     Y=None
    disp_flag=False
    capture=True
    first_frame=False
    next_frame=[]
    corners=[]
    img=[]
    nos = 20
#     storepath = 'output/'+str(label)+"/"
# #     storepath="dataset/"+str(label)+"/"+filename
#     if not os.path.exists(storepath):
#         os.mkdir(storepath)
#     fourcc = cv2.VideoWriter_fourcc(*'XVID')
#     out = cv2.VideoWriter(storepath+filename,fourcc, 20.0, (400,500))
    def mouse_click(event,x,y,flags,param):
        if event == cv2.EVENT_LBUTTONDOWN:
            corners.append([x,y])
#             print("fno"+str(fno))
            for i in corners:
                [x,y] = i
#                 cropped_im[y,x]=255
                cv2.circle(cropped_im,(x,y),3,255,-1)
#     label=None
#     TEST=None
#     GT=None
#     storepath="dataset/"+str(label)+"/"+filename
#     if not os.path.exists("dataset/"+str(label)):
#         os.mkdir("dataset/"+str(label))
#     if not os.path.exists(storepath):
#         os.mkdir(storepath)
    cv2.namedWindow(str(label)+":"+filename)
    cv2.setMouseCallback(str(label)+":"+filename, mouse_click)
    while True:
        # grab the current frame, then handle if we are using a
        # VideoStream or VideoCapture object
        frame1 = vs.read()
        frame = frame1[1] # if args.get("video", False) else frame1
        # frame = fgbg.apply(frame)

        # check to see if we have reached the end of the stream
        if frame is None:
            break

        # resize the frame (so we can process it faster) and grab the
        # frame dimensions
        frame = imutils.resize(frame, width=500)
        (H, W) = frame.shape[:2]

        # check to see if we are currently tracking an object
        if fno in boxes:
            (x1,y1,x2,y2) = boxes[fno]
#             cv2.rectangle(frame, (x1, y1), (x2, y2),
#                         (0, 255, 0), 2)
            if x2<x1:
                temp=x2
                x2=x1
                x1=temp
            if y2<y1:
                temp=y2
                y2=y1
                y1=temp
#             print(frame.shape)
#             print(boxes[fno])
            if x2>W:
                x2=W
            if y2>H:
                y2=H
            if x1<0:
                x1=0
            if y1<0:
                y1=0
            cropped_im = frame[y1:y2,x1:x2]
            [m,n,p] = cropped_im.shape
            diff = 400 - m
            top = int(diff/2)
            bot = diff -top
            diff = 500 - n
            left = int(diff/2)
            right = diff -left
            constant= cv2.copyMakeBorder(cropped_im,top,bot,left,right,cv2.BORDER_CONSTANT,value=[0,0,0])
#             print(constant.shape);
            if(capture):
#                 next_img = predictSilhouette(cropped_im)
#                 [m,n,p] = next_img.shape
#                 diff = 400 - m
#                 top = int(diff/2)
#                 bot = diff -top
#                 diff = 500 - n
#                 left = int(diff/2)
#                 right = diff -left
#                 padded_img= cv2.copyMakeBorder(next_img,top,bot,left,right,cv2.BORDER_CONSTANT,value=[0,0,0])
#                 out.write(padded_img)
                storepath = "training/"+str(label)+"/"
                if not os.path.exists(storepath):
                    os.mkdir(storepath)
                
                storepath = "training/"+str(label)+"/test/"
                if not os.path.exists(storepath):
                    os.mkdir(storepath)
                cv2.imwrite(storepath+'next_frame'+str(20-nos+1)+'.png',cropped_im)
                nos = nos-1
                if(nos==0):
                    capture=False

#             print(fno)                

            # show the output frame
#             cv2.imwrite(storepath+"/"+str(fno)+".png",cropped_im)
            if not first_frame:
                corners=[]
                img = copy.copy(cropped_im)
                while True:

                    key2 = cv2.waitKey(1) or 0xff
                    cv2.imshow(str(label)+":"+filename,cropped_im)

                    # cv2.imshow('frame', frame)

                    if key2 == ord('p'):
                        disp_flag=True
                        first_frame=True
                        break
            key = cv2.waitKey(20) & 0xFF
            
#         # if the `q` key was pressed, break from the loop
            if key == ord("q"):
                break
            if key == ord('p'):
                corners=[]
                img = copy.copy(cropped_im)
                while True:

                    key2 = cv2.waitKey(1) or 0xff
                    cv2.imshow(str(label)+":"+filename,cropped_im)
                    
                    # cv2.imshow('frame', frame)

                    if key2 == ord('p'):
                        disp_flag=True
                        break
            if disp_flag:
                if corners:
#                 img = frame[y1:y2,x1:x2]
#                 plt.imshow(img),plt.show()
#                 img = newim
                    mask = np.zeros((img.shape[0], img.shape[1]))
                    cv2.fillPoly(mask, [np.array(corners)], 1)

                    storepath = "training/"+str(label)+"/"
                    if not os.path.exists(storepath):
                        os.mkdir(storepath)
                    storepath = "training/"+str(label)+"/train/"
                    if not os.path.exists(storepath):
                        os.mkdir(storepath)
                    f1 = filename[:-len('.mp4')]
                    print(storepath+f1+'-frame.png')
                    cv2.imwrite(storepath+f1+'-frame.png',img)
                    cv2.imwrite(storepath+f1+'-gt.png',mask)
    #                 cv2.imshow("Mask:", mask)
                    mask = mask.astype(np.bool)
    #                 cv2.imshow("Mask:", mask)

                    silhouette = np.zeros_like(img)
                    silhouette[mask] = img[mask]
    #                 # delete zero columns
    #                 silhouette= np.delete(silhouette,np.where(~silhouette.any(axis=0))[0], axis=1)
    #                 # delete zero rows
    #                 silhouette= np.delete(silhouette,np.where(~silhouette.any(axis=1))[0], axis=0)


    #                 mask = np.zeros_like(frame,np.uint8)
    #                 rect = (x1,y1,x2-x1,y2-y1)
    #                 cv2.grabCut(frame,mask,rect,bgdModel,fgdModel,5,cv2.GC_INIT_WITH_RECT)

    #                 mask2 = np.where((mask==2)|(mask==0),0,1).astype('uint8')
    # #                 mask2.resize(frame.shape)
    #                 img = np.zeros([frame.shape[0],frame.shape[1],1,3])
    #                 img = img*mask2[:,:,np.newaxis]

    #                 mask = mask.astype(np.int8)
    #                 mask = np.where((mask==255)|(mask==0),0,1).astype('uint8')
    #                 mask, bgdModel, fgdModel = cv2.grabCut(img,mask,None,bgdModel,fgdModel,5,cv2.GC_INIT_WITH_MASK)
    #                 mask = np.where((mask==2)|(mask==0),0,1).astype('uint8')
    #                 img = img*mask[:,:,np.newaxis]
    #                 cv2.imshow("Grabcut:", img)
    #                 cv2.namedWindow('Silhouette:')
                    cv2.imwrite(storepath+f1+'-extracted_silhouette.png',silhouette)
    #                 cv2.imshow("Silhouette:", silhouette)
                    disp_flag=False
#                 capture = True
#             gray = cv2.cvtColor(cropped_im,cv2.COLOR_BGR2GRAY)

#             corners = cv2.goodFeaturesToTrack(gray,25,0.01,10)
#             corners = np.int0(corners)
#             print (corners)
#             cv2.drawContours(cropped_im, corners, -1, (0, 255, 0), 3)
#             for i in corners:
#                 [x,y] = i
#                 cv2.circle(cropped_im,(x,y),3,255,-1)

#             plt.imshow(img),plt.show()
            cv2.imshow(str(label)+":"+filename, cropped_im)
            
#             key = cv2.waitKey(1) & 0xFF

# #         # if the `q` key was pressed, break from the loop
#             if key == ord("q"):
#                 break

        fno=fno+1

    vs.release()
#     out.release()
    
    # close all windows
    cv2.destroyAllWindows()
#     data={'X':X,'Y':Y}
#     return data

# %%
basePath = "../IndianBirds/"
# X=None
# Y=None
# TEST=None
# GT=None
# a = {24 :["66ehMV8l17w", "h10IuNIRpgQ"],
# 22:["jSC8Wy3WhaI", "LkCuK5H0JSc"],
# 23:["-iHTKofq5cM", "8VWIz-yyYsw"]}
# 132,134,135,147,16,17,2-,20-,21,22,
# 23,25,36,52,53,54,55,56,57,59,61,
# 64,65,66,67,69,70,71,76,80,81,148,
# 151,158,166,170,172,177,180,188,5,
# 50,51,68,78,84,85,86,9,99,
for i in [81,148,151,158,166,170,172,177,180,188]:
    boxes = {}
    boxes2 = {}
    fullPath = basePath+str(i)+"/"
    allfiles = os.listdir(fullPath)
    if not os.path.exists(fullPath+"bbox.pkl"):
    	continue
    f = open(fullPath+"bbox.pkl","rb")
    boxes=pickle.load(f)
    f.close()
    if os.path.exists(fullPath+"bbox-2.pkl"):
        f = open(fullPath+"bbox-2.pkl","rb")
        boxes2=pickle.load(f)
        f.close()
#     allfiles.remove('C3wkLDsVUwM.mp4')
    j=0;
    storepath = "training/"+str(i)+"/train/"
#     box = boxes[allfiles[0]][221]
#     for file in allfiles:
    for file in boxes.keys():
#     for file in ["re3vrPS4RiU.mp4","UNiidxwuxO0.mp4"]:
#     for file in a[i]:
#         file = file+'.mp4'
#         if file.endswith(".mp4"):
#         if file in boxes2.keys():
#             print(file+" already present")
#             continue
        f1 = file[:-len('.mp4')]
#         print(storepath+f1+'-frame.png')
        if os.path.exists(storepath+f1+'-frame.png'):
            print("yes")
            continue
        print(file)
        trainVideo(fullPath+file,boxes[file],i,file)
#             if i==1:
#             if X is not None:
#                 X.append(data['X'])
#             else:
#                 X=data['X']

#             if Y is not None:
#                 Y.append(data['Y'])
#             else:
#                 Y=data['Y']

#         j=j+1
#         if (j==2):
#             break
#         boxes[file] = b
# Out:
# yes
# yes
# dOBPdJu5p4s.mp4
# training/81/train/dOBPdJu5p4s-frame.png
# yvWU1g0-OHc.mp4
# training/81/train/yvWU1g0-OHc-frame.png
# dBIvwFg1tik.mp4
# training/81/train/dBIvwFg1tik-frame.png
# 2gQZofavz8Q.mp4
# training/81/train/2gQZofavz8Q-frame.png
# 0X_yz2ci3QA.mp4
# training/81/train/0X_yz2ci3QA-frame.png
# LBaGd92ZTVA.mp4
# training/81/train/LBaGd92ZTVA-frame.png
# 12jE583ZSBo.mp4
# training/148/train/12jE583ZSBo-frame.png
# UTuDthAY8m4.mp4
# 5LVLZNRlmwM.mp4
# training/148/train/5LVLZNRlmwM-frame.png
# e6rEu4ajY3M.mp4
# training/148/train/e6rEu4ajY3M-frame.png
# VULiuxZ4J18.mp4
# training/148/train/VULiuxZ4J18-frame.png
# 286HyrHQb14.mp4
# training/148/train/286HyrHQb14-frame.png
# bXzIMmpZbFo.mp4
# training/148/train/bXzIMmpZbFo-frame.png
# 5H7R3XMWzjI.mp4
# training/151/train/5H7R3XMWzjI-frame.png
# QSiXrmQRf6Y.mp4
# training/151/train/QSiXrmQRf6Y-frame.png
# wMNBYqBa2-k.mp4
# training/151/train/wMNBYqBa2-k-frame.png
# NaC6Yim7_p4.mp4
# training/151/train/NaC6Yim7_p4-frame.png
# -O1xYqXuQ2o.mp4
# training/151/train/-O1xYqXuQ2o-frame.png
# 3zlnkjjfnns.mp4
# NhbcVNgiaT0.mp4
# training/151/train/NhbcVNgiaT0-frame.png
# tNRYn7yHrNI.mp4
# training/158/train/tNRYn7yHrNI-frame.png
# jnS4kTXhImg.mp4
# training/158/train/jnS4kTXhImg-frame.png
# 4MpJsEh0PY0.mp4
# training/158/train/4MpJsEh0PY0-frame.png
# training/158/train/4MpJsEh0PY0-frame.png
# aEpLk-o8uIU.mp4
# training/158/train/aEpLk-o8uIU-frame.png
# zV0V8sphyks.mp4
# training/158/train/zV0V8sphyks-frame.png
# MXyKcFWiOj0.mp4
# training/158/train/MXyKcFWiOj0-frame.png
# lTu9dOssKiA.mp4
# training/158/train/lTu9dOssKiA-frame.png
# 4DC6Npc9Lw0.mp4
# training/166/train/4DC6Npc9Lw0-frame.png
# 6YIdRIQzs9g.mp4
# training/166/train/6YIdRIQzs9g-frame.png
# 6LXqPpW1m2U.mp4
# a9zCQ9Fs7Po.mp4
# training/166/train/a9zCQ9Fs7Po-frame.png
# 9VLYTXlCAWI.mp4
# training/166/train/9VLYTXlCAWI-frame.png
# training/166/train/9VLYTXlCAWI-frame.png
# uvSoCyAsOZg.mp4
# training/166/train/uvSoCyAsOZg-frame.png
# vXloCJ5_w7k.mp4
# training/166/train/vXloCJ5_w7k-frame.png
# NAu3FiSSYuk.mp4
# training/170/train/NAu3FiSSYuk-frame.png
# training/170/train/NAu3FiSSYuk-frame.png
# cvLUObnFz1w.mp4
# training/170/train/cvLUObnFz1w-frame.png
# K5VM9EK8gYk.mp4
# training/170/train/K5VM9EK8gYk-frame.png
# kmpQzIWn2Gw.mp4
# training/170/train/kmpQzIWn2Gw-frame.png
# wEdCOiiM6l8.mp4
# training/170/train/wEdCOiiM6l8-frame.png
# 7Q87G3aiHRY.mp4
# training/170/train/7Q87G3aiHRY-frame.png
# GIlWzPvoFPc.mp4
# training/170/train/GIlWzPvoFPc-frame.png
# Vum4i48lEA4.mp4
# training/172/train/Vum4i48lEA4-frame.png
# 1wrWh8YgyrA.mp4
# training/172/train/1wrWh8YgyrA-frame.png
# cs8NQh5dAjk.mp4
# training/172/train/cs8NQh5dAjk-frame.png
# cZGqvldp-WQ.mp4
# training/172/train/cZGqvldp-WQ-frame.png
# b-Lui36jDyo.mp4
# training/172/train/b-Lui36jDyo-frame.png
# mM_VNpFcMfQ.mp4
# training/172/train/mM_VNpFcMfQ-frame.png
# E7borwrvKiA.mp4
# training/172/train/E7borwrvKiA-frame.png
# AKXu8_xzW7Y.mp4
# training/177/train/AKXu8_xzW7Y-frame.png
# YI6Rm20DlHo.mp4
# training/177/train/YI6Rm20DlHo-frame.png
# qw7yjjlkc7c.mp4
# training/177/train/qw7yjjlkc7c-frame.png
# _j6z1Ut-i-c.mp4
# training/177/train/_j6z1Ut-i-c-frame.png
# training/177/train/_j6z1Ut-i-c-frame.png
# _eKy_X7ZJ-M.mp4
# training/177/train/_eKy_X7ZJ-M-frame.png
# pCbdFHJ55QQ.mp4
# training/177/train/pCbdFHJ55QQ-frame.png
# z81-fEBUtaU.mp4
# training/177/train/z81-fEBUtaU-frame.png
# OgevmBdBoKs.mp4
# training/180/train/OgevmBdBoKs-frame.png
# q4YfoVcMGSw.mp4
# training/180/train/q4YfoVcMGSw-frame.png
# R0ZQovQtOAI.mp4
# training/180/train/R0ZQovQtOAI-frame.png
# Rk5UTvaDF-E.mp4
# training/180/train/Rk5UTvaDF-E-frame.png
# uhgLYAV8XuU.mp4
# training/180/train/uhgLYAV8XuU-frame.png
# OkzBzxFSUNw.mp4
# training/180/train/OkzBzxFSUNw-frame.png
# Xy20Wb7sl-I.mp4
# training/180/train/Xy20Wb7sl-I-frame.png
# 8mlLV73jfhw.mp4
# training/188/train/8mlLV73jfhw-frame.png
# v7nOXPQ-cgg.mp4
# training/188/train/v7nOXPQ-cgg-frame.png
# gFP9YCQb8ZI.mp4
# training/188/train/gFP9YCQb8ZI-frame.png
# i4q_PzG-yec.mp4
# training/188/train/i4q_PzG-yec-frame.png
# 5u0mPlnrqwY.mp4
# training/188/train/5u0mPlnrqwY-frame.png
# bAom9gEoY2Q.mp4
# training/188/train/bAom9gEoY2Q-frame.png
# RTPxwnlIN1E.mp4
# training/188/train/RTPxwnlIN1E-frame.png

# %%
boxes.keys()
# Out:
# dict_keys(['vRWD1MraURw.mp4', 'content.mp4'])

# %%
a
# Out:
# {11: ['_4HSoT3Jxqc', 'mXQQkeHwqcs'],
#  12: ['LfoZ7WTSkoU', '9IMlpMU2oJM'],
#  13: ['nDdPWmR2iVI', '88UmpHqyIZo']}

# %%
a[11]
# Out:
# ['_4HSoT3Jxqc', 'mXQQkeHwqcs']
